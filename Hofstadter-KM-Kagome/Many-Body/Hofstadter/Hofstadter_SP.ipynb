# %%
using QuantumOptics
using Revise
using OffsetArrays
using LinearAlgebra
using Plots

# %%
includet("Hofstadter_SP.jl")

# %%
Nx = 5
Ny = 5
p = 1
q = 5

N_Site = Nx*Ny
t = 1
NPhi0 = Int(Nx*Ny*(p/q))
Cut_Off = NPhi0
# Out:
# 5

# %%
H = Hofstadter_SP(Nx, Ny, p/q ,0);

# %%
E, λ = eigen(H)
scatter(E)
