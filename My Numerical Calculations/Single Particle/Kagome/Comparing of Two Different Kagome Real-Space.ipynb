# %%
import sys
sys.path.insert(0, 'C:/Users/Can/Dropbox/PC (2)/Desktop/My Numerical Calculations/Single Particle/Kagome')
# %matplotlib notebook

# %%
from Real_Kagome_Lattice_v1 import *
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users/Can/Dropbox/PC (2)/Desktop/My Numerical Calculations/Single Particle/Kagome\Real_Kagome_Lattice_v1.py:52: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   points = np.vstack({tuple(e) for e in points})

# %%
from Real_Kagome_Lattice_v2 import *
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig0, ax0 = plt.subplots()

x_real = np.arange(0, len(points), 1)

E1, U1 = np.linalg.eig(Hamiltonian_1())
idx_1 = np.argsort(E1)
sorted_1 = E1[idx_1]
y_real_1 = sorted_1

E2, U2 = np.linalg.eig(H)
idx_2 = np.argsort(E2)
sorted_2 = E2[idx_2]
y_real_2 = sorted_2

ax0.plot(x_real, y_real_1, 'bo', markersize=1.0)
ax0.plot(x_real, y_real_1, 'ro', markersize=1.8, alpha=0.2)

ax0.set_xlabel(r"$n$")
ax0.set_ylabel(r'$E$')
ax0.set_title(r'$N_{site}= $'+str(len(points))+'\n'+r'$t_1: $'+str(t1)+' , '+r'$\lambda_1: $'+str(L1)+' , '+r'$t_2: $'+str(t2)+' , '+r'$\lambda_2: $'+str(L2))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, '$N_{site}= $48\n$t_1: $-1 , $\\lambda_1: $0.28 , $t_2: $0.3 , $\\lambda_2: $0.2')
